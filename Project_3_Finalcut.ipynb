# %%
# !pip install ts2vg
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 4.9 MB/s
# ...

# %%
# !pip install igraph
# Out:
# ...
#      |████████████████████████████████| 3.2 MB 5.0 MB/s
# ...

# %%
# !pip install pycairo
# !pip install cairocffi
# Out:
# ...
#      |████████████████████████████████| 344 kB 5.2 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   ERROR: Failed building wheel for pycairo
# Failed to build pycairo
# ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
# ...
#      |████████████████████████████████| 88 kB 2.7 MB/s
# ...
#   Created wheel for cairocffi: filename=cairocffi-1.3.0-py3-none-any.whl size=89667 sha256=846d4467f115b46cfe378f205c523b2da7677b1a26aa7212a552a1c71fdc6139
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/e1/5c8a9692a27f639a07c949044bec943f26c81cd53d3805319f
# Successfully built cairocffi
# ...

# %%
#Task-1
from google.colab import files
uploaded = files.upload()

# %%
import pandas as pd
climbingdown_subject1 = pd.read_csv('climbingdown_subject1.csv')
climbingdown_subject2 = pd.read_csv('climbingdown_subject2.csv')
climbingdown_subject3 = pd.read_csv('climbingdown_subject3.csv')
climbingdown_subject4 = pd.read_csv('climbingdown_subject4.csv')
climbingdown_subject5 = pd.read_csv('climbingdown_subject5.csv')
climbingdown_subject6 = pd.read_csv('climbingdown_subject6.csv')
climbingdown_subject7 = pd.read_csv('climbingdown_subject7.csv')
climbingdown_subject8 = pd.read_csv('climbingdown_subject8.csv')
climbingdown_subject9 = pd.read_csv('climbingdown_subject9.csv')
climbingdown_subject10 = pd.read_csv('climbingdown_subject10.csv')
climbingdown_subject11 = pd.read_csv('climbingdown_subject11.csv')
climbingdown_subject12 = pd.read_csv('climbingdown_subject12.csv')
climbingdown_subject13 = pd.read_csv('climbingdown_subject13.csv')
climbingdown_subject14 = pd.read_csv('climbingdown_subject14.csv')
climbingdown_subject15 = pd.read_csv('climbingdown_subject15.csv')

climbingup_subject1 = pd.read_csv('climbingup_subject1.csv')
climbingup_subject2 = pd.read_csv('climbingup_subject2.csv')
climbingup_subject3 = pd.read_csv('climbingup_subject3.csv')
climbingup_subject4 = pd.read_csv('climbingup_subject4.csv')
climbingup_subject5 = pd.read_csv('climbingup_subject5.csv')
climbingup_subject6 = pd.read_csv('climbingup_subject6.csv')
climbingup_subject7 = pd.read_csv('climbingup_subject7.csv')
climbingup_subject8 = pd.read_csv('climbingup_subject8.csv')
climbingup_subject9 = pd.read_csv('climbingup_subject9.csv')
climbingup_subject10 = pd.read_csv('climbingup_subject10.csv')
climbingup_subject11 = pd.read_csv('climbingup_subject11.csv')
climbingup_subject12 = pd.read_csv('climbingup_subject12.csv')
climbingup_subject13 = pd.read_csv('climbingup_subject13.csv')
climbingup_subject14 = pd.read_csv('climbingup_subject14.csv')
climbingup_subject15 = pd.read_csv('climbingup_subject15.csv')

running_subject1 = pd.read_csv('running_subject1.csv')
running_subject2 = pd.read_csv('running_subject2.csv')
running_subject3 = pd.read_csv('running_subject3.csv')
running_subject4 = pd.read_csv('running_subject4.csv')
running_subject5 = pd.read_csv('running_subject5.csv')
running_subject6 = pd.read_csv('running_subject6.csv')
running_subject7 = pd.read_csv('running_subject7.csv')
running_subject8 = pd.read_csv('running_subject8.csv')
running_subject9 = pd.read_csv('running_subject9.csv')
running_subject10 = pd.read_csv('running_subject10.csv')
running_subject11 = pd.read_csv('running_subject11.csv')
running_subject12 = pd.read_csv('running_subject12.csv')
running_subject13 = pd.read_csv('running_subject13.csv')
running_subject14 = pd.read_csv('running_subject14.csv')
running_subject15 = pd.read_csv('running_subject15.csv')

walking_subject1 = pd.read_csv('walking_subject1.csv')
walking_subject2 = pd.read_csv('walking_subject2.csv')
walking_subject3 = pd.read_csv('walking_subject3.csv')
walking_subject4 = pd.read_csv('walking_subject4.csv')
walking_subject5 = pd.read_csv('walking_subject5.csv')
walking_subject6 = pd.read_csv('walking_subject6.csv')
walking_subject7 = pd.read_csv('walking_subject7.csv')
walking_subject8 = pd.read_csv('walking_subject8.csv')
walking_subject9 = pd.read_csv('walking_subject9.csv')
walking_subject10 = pd.read_csv('walking_subject10.csv')
walking_subject11 = pd.read_csv('walking_subject11.csv')
walking_subject12 = pd.read_csv('walking_subject12.csv')
walking_subject13 = pd.read_csv('walking_subject13.csv')
walking_subject14 = pd.read_csv('walking_subject14.csv')
walking_subject15 = pd.read_csv('walking_subject15.csv')

# %%
#Storing the dataframes in a list for easy iteration with loop
List1=[climbingdown_subject1,climbingdown_subject2,climbingdown_subject3,climbingdown_subject4, climbingdown_subject5,climbingdown_subject6,
       climbingdown_subject7,climbingdown_subject8,climbingdown_subject9,climbingdown_subject10,climbingdown_subject11,climbingdown_subject12,
       climbingdown_subject13,climbingdown_subject14,climbingdown_subject15]

List2=[climbingup_subject1,climbingup_subject2,climbingup_subject3,climbingup_subject4, climbingup_subject5,climbingup_subject6,
       climbingup_subject7,climbingup_subject8,climbingup_subject9,climbingup_subject10,climbingup_subject11,climbingup_subject12,
       climbingup_subject13,climbingup_subject14,climbingup_subject15]
	   
List3=[running_subject1,running_subject2,running_subject3,running_subject4, running_subject5,running_subject6,
       running_subject7,running_subject8,running_subject9,running_subject10,running_subject11,running_subject12,
       running_subject13,running_subject14,running_subject15]
	   
List4=[walking_subject1,walking_subject2,walking_subject3,walking_subject4, walking_subject5,walking_subject6,
       walking_subject7,walking_subject8,walking_subject9,walking_subject10,walking_subject11,walking_subject12,
       walking_subject13,walking_subject14,walking_subject15]

# %%
#Nested list
List=[List1,List2,List3,List4]

# %%
pip install tabulate

# %%
from tabulate import tabulate

# %%
from ts2vg import NaturalVG
from ts2vg import HorizontalVG
import numpy as np
data = []
for p in range(0,2):
  for x in range(0,4): 
    for y in range(0,15):
      if p == 0:
        g = HorizontalVG()
        Method = 'HVG'
      else:
        g = NaturalVG()
        Method = 'NVG'

      g.build(List[x][y]['attr_x'][1000:2024])
      ig_g = g.as_igraph()
      if x == 0:
        Activity = 'Climbing down'
      elif x == 1:
        Activity = 'Climbing up'
      elif x == 2:
        Activity = 'Running'
      else :
        Activity = 'Walking'
      table = {'Method' : [Method], 'Subject' : ['Subject'+str(y+1)], 'Accelerometer_axis' : ['attr_x'] , 'Average_degree' : [np.mean(ig_g.degree())], 'Network_diameter' : [ig_g.diameter()], 
             'Average_Path_Length' : ig_g.average_path_length(), 'Activity' : [Activity]}
      df = pd.DataFrame(data=table)
      data.append(df)


for p in range(0,2):
  for x in range(0,4): 
    for y in range(0,15):
      if p == 0:
        g = HorizontalVG()
        Method = 'HVG'
      else:
        g = NaturalVG()
        Method = 'NVG'
      g.build(List[x][y]['attr_y'][1000:2024])
      ig_g = g.as_igraph()
      if x == 0:
        Activity = 'Climbing down'
      elif x == 1:
        Activity = 'Climbing up'
      elif x == 2:
        Activity = 'Running'
      else :
        Activity = 'Walking'
      table = {'Method' : [Method], 'Subject' : ['Subject'+str(y+1)], 'Accelerometer_axis' : ['attr_y'] , 'Average_degree' : [np.mean(ig_g.degree())], 'Network_diameter' : [ig_g.diameter()], 
              'Average_Path_Length' : ig_g.average_path_length(), 'Activity' : [Activity]}
      df = pd.DataFrame(data=table)
      data.append(df)


for p in range(0,2):
  for x in range(0,4): 
    for y in range(0,15):
      if p == 0:
        g = HorizontalVG()
        Method = 'HVG'
      else:
        g = NaturalVG()
        Method = 'NVG'
      g.build(List[x][y]['attr_z'][1000:2024])
      ig_g = g.as_igraph()
      if x == 0:
        Activity = 'Climbing down'
      elif x == 1:
        Activity = 'Climbing up'
      elif x == 2:
        Activity = 'Running'
      else :
        Activity = 'Walking'
      table = {'Method' : [Method], 'Subject' : ['Subject'+str(y+1)], 'Accelerometer_axis' : ['attr_z'] , 'Average_degree' : [np.mean(ig_g.degree())], 'Network_diameter' : [ig_g.diameter()], 
              'Average_Path_Length' : ig_g.average_path_length(), 'Activity' : [Activity]}
      df = pd.DataFrame(data=table)
      data.append(df)

# %%
#Tabulation
output = pd.concat(data)
print(tabulate(output, headers = 'keys', tablefmt = 'grid'))

# %%
#Plotting for walking and running
import numpy as np
import matplotlib.pyplot as plt

newdf1 = output[(output.Activity == "Walking") & (output.Method == "HVG") & (output.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output[(output.Activity == "Running") & (output.Method == "HVG") & (output.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('1) Average degree vs Network diameter, Accelerometer_axis - attr_x, method - HVG')
plt.show()



newdf1 = output[(output.Activity == "Walking") & (output.Method == "HVG") & (output.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output[(output.Activity == "Running") & (output.Method == "HVG") & (output.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('2) Average degree vs Network diameter, Accelerometer_axis - attr_y, method - HVG')
plt.show()



newdf1 = output[(output.Activity == "Walking") & (output.Method == "HVG") & (output.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output[(output.Activity == "Running") & (output.Method == "HVG") & (output.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('3) Average degree vs Network diameter, Accelerometer_axis - attr_z, method - HVG')
plt.show()



newdf1 = output[(output.Activity == "Walking") & (output.Method == "NVG") & (output.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output[(output.Activity == "Running") & (output.Method == "NVG") & (output.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('4) Average degree vs Network diameter, Accelerometer_axis - attr_x, method - NVG')
plt.show()



newdf1 = output[(output.Activity == "Walking") & (output.Method == "NVG") & (output.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output[(output.Activity == "Running") & (output.Method == "NVG") & (output.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('5) Average degree vs Network diameter, Accelerometer_axis - attr_y, method - NVG')
plt.show()



newdf1 = output[(output.Activity == "Walking") & (output.Method == "NVG") & (output.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')


newdf1 = output[(output.Activity == "Running") & (output.Method == "NVG") & (output.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('6) Average degree vs Network diameter, Accelerometer_axis - attr_z, method - NVG')
plt.show()

# %%
#Plotting for climbing up and climbing down
newdf1 = output[(output.Activity == 'Climbing down') & (output.Method == "HVG") & (output.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')

newdf1 = output[(output.Activity == 'Climbing up') & (output.Method == "HVG") & (output.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')
plt.legend() 
plt.title('1) Average degree vs Network diameter, Accelerometer_axis - attr_x, method - HVG')
plt.show()



newdf1 = output[(output.Activity == 'Climbing down') & (output.Method == "HVG") & (output.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')

newdf1 = output[(output.Activity == 'Climbing up') & (output.Method == "HVG") & (output.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')
plt.legend() 
plt.title('2) Average degree vs Network diameter, Accelerometer_axis - attr_y, method - HVG')
plt.show()



newdf1 = output[(output.Activity == 'Climbing down') & (output.Method == "HVG") & (output.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')

newdf1 = output[(output.Activity == 'Climbing up') & (output.Method == "HVG") & (output.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')
plt.legend() 
plt.title('3) Average degree vs Network diameter, Accelerometer_axis - attr_z, method - HVG')
plt.show()



newdf1 = output[(output.Activity == 'Climbing down') & (output.Method == "NVG") & (output.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')

newdf1 = output[(output.Activity == 'Climbing up') & (output.Method == "NVG") & (output.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')
plt.legend() 
plt.title('4) Average degree vs Network diameter, Accelerometer_axis - attr_x, method - NVG')
plt.show()



newdf1 = output[(output.Activity == 'Climbing down') & (output.Method == "NVG") & (output.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')

newdf1 = output[(output.Activity == 'Climbing up') & (output.Method == "NVG") & (output.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')
plt.legend() 
plt.title('5) Average degree vs Network diameter, Accelerometer_axis - attr_y, method - NVG')
plt.show()



newdf1 = output[(output.Activity == 'Climbing down') & (output.Method == "NVG") & (output.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')

newdf1 = output[(output.Activity == 'Climbing up') & (output.Method == "NVG") & (output.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Average_degree"]
y = newdf1.loc[:,"Network_diameter"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')
plt.legend() 
plt.title('6) Average degree vs Network diameter, Accelerometer_axis - attr_z, method - NVG')
plt.show()

# %%
#Task-2
#Functions
import numpy as np


def s_entropy(freq_list):
    ''' This function computes the shannon entropy of a given frequency distribution.
    USAGE: shannon_entropy(freq_list)
    ARGS: freq_list = Numeric vector representing the frequency distribution
    OUTPUT: A numeric value representing shannon's entropy'''
    freq_list = [element for element in freq_list if element != 0]
    sh_entropy = 0.0
    for freq in freq_list:
        sh_entropy += freq * np.log(freq)
    sh_entropy = -sh_entropy
    return(sh_entropy)

def ordinal_patterns(ts, embdim, embdelay):
    ''' This function computes the ordinal patterns of a time series for a given embedding dimension and embedding delay.
    USAGE: ordinal_patterns(ts, embdim, embdelay)
    ARGS: ts = Numeric vector representing the time series, embdim = embedding dimension (3<=embdim<=7 prefered range), embdelay =  embdding delay
    OUPTUT: A numeric vector representing frequencies of ordinal patterns'''
    m, t = embdim, embdelay
    x = ts if isinstance(ts, np.ndarray) else np.array(ts) 

    tmp = np.zeros((x.shape[0], m))
    for i in range(m):
        tmp[:, i] = np.roll(x, i*t)
    partition = tmp[(t*m-1):, :] 
    permutation = np.argsort(partition)
    idx = _hash(permutation)

    counts = np.zeros(np.math.factorial(m))
    for i in range(counts.shape[0]):
        counts[i] = (idx == i).sum()
    return list(counts[counts != 0].astype(int))

def _hash(x):
    m, n = x.shape
    if n == 1:
        return np.zeros(m)
    return np.sum(np.apply_along_axis(lambda y: y < x[:, 0], 0, x), axis=1) * np.math.factorial(n-1) + _hash(x[:, 1:]) 
    

def p_entropy(op):
    ordinal_pat = op
    max_entropy = np.log(len(ordinal_pat))
    p = np.divide(np.array(ordinal_pat), float(sum(ordinal_pat)))
    return(s_entropy(p)/max_entropy)

def complexity(op):
    ''' This function computes the complexity of a time series defined as: Comp_JS = Q_o * JSdivergence * pe
    Q_o = Normalizing constant
    JSdivergence = Jensen-Shannon divergence
    pe = permutation entopry
    ARGS: ordinal pattern'''
    pe = p_entropy(op)
    constant1 = (0.5+((1 - 0.5)/len(op)))* np.log(0.5+((1 - 0.5)/len(op)))
    constant2 = ((1 - 0.5)/len(op))*np.log((1 - 0.5)/len(op))*(len(op) - 1)
    constant3 = 0.5*np.log(len(op))
    Q_o = -1/(constant1+constant2+constant3)

    temp_op_prob = np.divide(op, sum(op))
    temp_op_prob2 = (0.5*temp_op_prob)+(0.5*(1/len(op)))
    JSdivergence = (s_entropy(temp_op_prob2) - 0.5 * s_entropy(temp_op_prob) - 0.5 * np.log(len(op)))
    Comp_JS = Q_o * JSdivergence * pe
    return(Comp_JS)

# %%
#Computing the permutation entropy and complexity for all the parameters
data1 = []
for p in range(0,15):
  for x in range(0,3): 
    for y in range(3,7):
      for a in range(1,4):
        for z in range(0,4):

          if x == 0:
            sig_len = 1024
          elif x == 1:
            sig_len = 2048
          else :
            sig_len = 4096

          if z == 0:
            Activity = 'Climbing down'
          elif z == 1:
            Activity = 'Climbing up'
          elif z == 2:
            Activity = 'Running'
          else :
            Activity = 'Walking'

          op = ordinal_patterns(List[z][p]['attr_x'][0:sig_len],y,a)
          
          table = {'Subject' : ['Subject'+str(p+1)], 'Accelerometer_axis' : ['attr_x'] , 'Signal_length' : [sig_len], 'Dimension' : [y], 'Delay' : [a], 
                   'Permutation_entropy' : [p_entropy(op)], 'Complexity' : [complexity(op)], 'Activity' : [Activity]}
          df = pd.DataFrame(data=table)
          data1.append(df)


for p in range(0,15):
  for x in range(0,3): 
    for y in range(3,7):
      for a in range(1,4):
        for z in range(0,4):

          if x == 0:
            sig_len = 1024
          elif x == 1:
            sig_len = 2048
          else :
            sig_len = 4096

          if z == 0:
            Activity = 'Climbing down'
          elif z == 1:
            Activity = 'Climbing up'
          elif z == 2:
            Activity = 'Running'
          else :
            Activity = 'Walking'

          op = ordinal_patterns(List[z][p]['attr_y'][0:sig_len],y,a)
          
          table = {'Subject' : ['Subject'+str(p+1)], 'Accelerometer_axis' : ['attr_y'] , 'Signal_length' : [sig_len], 'Dimension' : [y], 'Delay' : [a], 
                   'Permutation_entropy' : [p_entropy(op)], 'Complexity' : [complexity(op)], 'Activity' : [Activity]}
          df = pd.DataFrame(data=table)
          data1.append(df)

for p in range(0,15):
  for x in range(0,3): 
    for y in range(3,7):
      for a in range(1,4):
        for z in range(0,4):

          if x == 0:
            sig_len = 1024
          elif x == 1:
            sig_len = 2048
          else :
            sig_len = 4096

          if z == 0:
            Activity = 'Climbing down'
          elif z == 1:
            Activity = 'Climbing up'
          elif z == 2:
            Activity = 'Running'
          else :
            Activity = 'Walking'

          op = ordinal_patterns(List[z][p]['attr_z'][0:sig_len],y,a)
          
          table = {'Subject' : ['Subject'+str(p+1)], 'Accelerometer_axis' : ['attr_z'] , 'Signal_length' : [sig_len], 'Dimension' : [y], 'Delay' : [a], 
                   'Permutation_entropy' : [p_entropy(op)], 'Complexity' : [complexity(op)], 'Activity' : [Activity]}
          df = pd.DataFrame(data=table)
          data1.append(df)

# %%
#Tabulation
output1 = pd.concat(data1)
print(tabulate(output1, headers = 'keys', tablefmt = 'grid'))

# %%
#Plotting walking vs running

import numpy as np
import matplotlib.pyplot as plt


newdf1 = output1[(output1.Activity == "Walking") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 3) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output1[(output1.Activity == "Running") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 3) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('1) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 3, Accelerometer_axis - attr_x')
plt.show()



newdf1 = output1[(output1.Activity == "Walking") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 4) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output1[(output1.Activity == "Running") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 4) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('2) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 4, Accelerometer_axis - attr_x')
plt.show()



newdf1 = output1[(output1.Activity == "Walking") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 5) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output1[(output1.Activity == "Running") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 5) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('3) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 5, Accelerometer_axis - attr_x')
plt.show()



newdf1 = output1[(output1.Activity == "Walking") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 6) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output1[(output1.Activity == "Running") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 6) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('4) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 6, Accelerometer_axis - attr_x')
plt.show()



newdf1 = output1[(output1.Activity == "Walking") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 3) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output1[(output1.Activity == "Running") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 3) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('5) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 3, Accelerometer_axis - attr_y')
plt.show()



newdf1 = output1[(output1.Activity == "Walking") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 4) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output1[(output1.Activity == "Running") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 4) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('6) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 4, Accelerometer_axis - attr_y')
plt.show()



newdf1 = output1[(output1.Activity == "Walking") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 5) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output1[(output1.Activity == "Running") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 5) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('7) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 5, Accelerometer_axis - attr_y')
plt.show()



newdf1 = output1[(output1.Activity == "Walking") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 6) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output1[(output1.Activity == "Running") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 6) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('8) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 6, Accelerometer_axis - attr_y')
plt.show()



newdf1 = output1[(output1.Activity == "Walking") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 3) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output1[(output1.Activity == "Running") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 3) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('9) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 3, Accelerometer_axis - attr_z')
plt.show()



newdf1 = output1[(output1.Activity == "Walking") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 4) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output1[(output1.Activity == "Running") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 4) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('10) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 4, Accelerometer_axis - attr_z')
plt.show()



newdf1 = output1[(output1.Activity == "Walking") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 5) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output1[(output1.Activity == "Running") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 5) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('11) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 5, Accelerometer_axis - attr_z')
plt.show()



newdf1 = output1[(output1.Activity == "Walking") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 6) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Walking')

newdf1 = output1[(output1.Activity == "Running") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 6) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Running')
plt.legend() 
plt.title('12) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 6, Accelerometer_axis - attr_z')
plt.show()

# %%
#Plotting climbing up vs climbing down
newdf1 = output1[(output1.Activity == "Climbing up") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 3) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')

newdf1 = output1[(output1.Activity == "Climbing down") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 3) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')
plt.legend() 
plt.title('1) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 3, Accelerometer_axis - attr_x')
plt.show()



newdf1 = output1[(output1.Activity == "Climbing up") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 4) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')

newdf1 = output1[(output1.Activity == "Climbing down") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 4) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')
plt.legend() 
plt.title('2) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 4, Accelerometer_axis - attr_x')
plt.show()



newdf1 = output1[(output1.Activity == "Climbing up") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 5) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')

newdf1 = output1[(output1.Activity == "Climbing down") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 5) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')
plt.legend() 
plt.title('3) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 5, Accelerometer_axis - attr_x')
plt.show()



newdf1 = output1[(output1.Activity == "Climbing up") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 6) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')

newdf1 = output1[(output1.Activity == "Climbing down") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 6) & (output1.Accelerometer_axis == "attr_x")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')
plt.legend() 
plt.title('4) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 6, Accelerometer_axis - attr_x')
plt.show()



newdf1 = output1[(output1.Activity == "Climbing up") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 3) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')

newdf1 = output1[(output1.Activity == "Climbing down") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 3) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')
plt.legend() 
plt.title('5) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 3, Accelerometer_axis - attr_y')
plt.show()



newdf1 = output1[(output1.Activity == "Climbing up") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 4) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')

newdf1 = output1[(output1.Activity == "Climbing down") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 4) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')
plt.legend() 
plt.title('6) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 4, Accelerometer_axis - attr_y')
plt.show()



newdf1 = output1[(output1.Activity == "Climbing up") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 5) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')

newdf1 = output1[(output1.Activity == "Climbing down") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 5) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')
plt.legend() 
plt.title('7) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 5, Accelerometer_axis - attr_y')
plt.show()



newdf1 = output1[(output1.Activity == "Climbing up") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 6) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')

newdf1 = output1[(output1.Activity == "Climbing down") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 6) & (output1.Accelerometer_axis == "attr_y")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')
plt.legend() 
plt.title('8) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 6, Accelerometer_axis - attr_y')
plt.show()



newdf1 = output1[(output1.Activity == "Climbing up") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 3) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')

newdf1 = output1[(output1.Activity == "Climbing down") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 3) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')
plt.legend() 
plt.title('9) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 3, Accelerometer_axis - attr_z')
plt.show()



newdf1 = output1[(output1.Activity == "Climbing up") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 4) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')

newdf1 = output1[(output1.Activity == "Climbing down") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 4) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')
plt.legend() 
plt.title('10) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 4, Accelerometer_axis - attr_z')
plt.show()



newdf1 = output1[(output1.Activity == "Climbing up") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 5) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')

newdf1 = output1[(output1.Activity == "Climbing down") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 5) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')
plt.legend() 
plt.title('11) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 5, Accelerometer_axis - attr_z')
plt.show()



newdf1 = output1[(output1.Activity == "Climbing up") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 6) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "g"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing up')

newdf1 = output1[(output1.Activity == "Climbing down") & (output1.Signal_length == 4096) & (output1.Delay == 1) & (output1.Dimension == 6) & (output1.Accelerometer_axis == "attr_z")]
x = newdf1.loc[:,"Permutation_entropy"]
y = newdf1.loc[:,"Complexity"]
color = "r"
plt.scatter(x, y, c = color, alpha=0.5, label = 'Climbing down')
plt.legend() 
plt.title('12) Permutation entropy vs Complexity, Signal_length - 4096, Embedded_delay - 1, Embedded_dimension - 6, Accelerometer_axis - attr_z')
plt.show()
